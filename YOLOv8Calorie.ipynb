# %% [markdown]
# <a href="https://colab.research.google.com/github/edwwwi/Bodyscope/blob/main/YOLOv8Calorie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training Phase

# %%
# !unzip FoodDataset.zip -d /content/sample_data/dataset
# Out:
# unzip:  cannot find or open FoodDataset.zip, FoodDataset.zip.zip or FoodDataset.zip.ZIP.

# %%
# !find /content/sample_data -maxdepth 4 -type d
# Out:
# /content/sample_data

# %%
# !ls /content/sample_data/
# Out:
# anscombe.json		      data.yaml		     README.dataset.txt   test
# california_housing_test.csv   mnist_test.csv	     README.md		  train
# california_housing_train.csv  mnist_train_small.csv  README.roboflow.txt  valid

# %%
# !ls /content/sample_data/train/images | head
# !ls /content/sample_data/train/images | wc -l
# Out:
# 0001900_jpg.rf.54c70122e65f24e718a095c77adc7e30.jpg
# 0014af7366_jpg.rf.6683d773c07569df65bc30fca679d127.jpg
# 006ae9ac8c_jpg.rf.2e675abbf1c975c0a3e7dcb67847ca34.jpg
# 00ed35e838_jpg.rf.d665fa7cfa20410a49f6b93f7420ad36.jpg
# 01ba86f373_jpg.rf.3a7a0ed694ea57f2361dd90a102aab46.jpg
# 02df621fdd_jpg.rf.b5989cb87c2aff4a8dc6d179be9b8e4e.jpg
# 02f4d344b4_jpg.rf.f965629e5d44f1ddb38d305ed0a8fba0.jpg
# 03052018_tandoorichai_01_jpg.rf.4dd4e0433299a016a8a945e491535ddd.jpg
# 03052018_tandoorichai_04-1024x683_jpg.rf.52e6b044e2ee2155eabb3cb8171a0d92.jpg
# 03b0fedc34_jpg.rf.f7ffcd443fbe26b4fbae14ae8b8845e2.jpg
# 1625

# %%
# !sed -i 's|path:.*|path: /content/sample_data|' /content/sample_data/data.yaml
# !sed -i 's|train:.*|train: train/images|' /content/sample_data/data.yaml
# !sed -i 's|val:.*|val: valid/images|' /content/sample_data/data.yaml
# !sed -i 's|test:.*|test: test/images|' /content/sample_data/data.yaml

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.3 MB/s eta 0:00:00
# ...

# %%
# !yolo detect train \
  model=yolov8n.pt \
  data=/content/sample_data/data.yaml \
  epochs=50 \
  imgsz=640 \
  batch=8 \
  project=/content/drive/MyDrive/yolo_runs \
  name=food_yolov8
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
